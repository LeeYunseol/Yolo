# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd /content/drive/MyDrive/Yolo

# %%
# !git clone https://LEEYunseol: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@github.com/LEEYunseol/Yolo.git

# %%
cd /content/drive/MyDrive/Yolo

# %%
# !git config --global user.name "Hyunjae"
# !git config --global user.email "hyunjea414@gmail.com"

# %%
# !git add --all

# %%
# !git commit -m "test"
# !git push

# %%
print('바보')
